# %%
from src.ml.training import AWSCostTrainer

trainer = AWSCostTrainer({
    'epochs': 50,
    'batch_size': 32,
    'model_dir': '../models'
})
trainer.train('../data/raw/aws_billing.csv')
